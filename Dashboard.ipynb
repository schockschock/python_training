# %%
import ipywidgets as widgets
import pandas as pd

style = {'description_width': 'initial'}

limit_case = widgets.IntSlider(
    value=1000,
    min=100,
    max=5000,
    step=1,
    description='Max Number of Case:',
    disabled=False,
    style=style)

# %%
def update_df_length(limit):
    
    df = pd.read_csv('melb_data.csv')
    df = df.iloc[0:limit, :]
    print("Number of rows in the dataset that have been successfully loaded:"+str(len(df)))

# %%
widgets.interactive(update_df_length, limit=limit_case)
# Out:
# interactive(children=(IntSlider(value=1000, description='Max Number of Case:', max=5000, min=100, style=Slider…

# %%
df = pd.read_csv('melb_data.csv')
df[df['CouncilArea']!='Yarra']
# Out:
#               Suburb         Address  Rooms Type      Price Method   SellerG  \
# 38      Airport West   154 Halsey Rd      3    t   840000.0     PI    Nelson
# 39      Airport West   50 Bedford St      3    h   730000.0     VB    Nelson
# 40      Airport West   50 Bedford St      3    h   770000.0     SP    Nelson
# 41      Airport West      23 Hart St      2    h   603000.0      S    Nelson
# 42      Airport West  1/80 Hawker St      3    t   700000.0      S      Brad
# ...              ...             ...    ...  ...        ...    ...       ...
# 13575  Wheelers Hill    12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown   77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown     83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown    96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville      6 Agnes St      4    h  1285000.0     SP   Village
#
# ...

# %%
df = pd.read_csv('melb_data.csv')
df[df['CouncilArea']!='Yarra']
# Out:
#               Suburb         Address  Rooms Type      Price Method   SellerG  \
# 38      Airport West   154 Halsey Rd      3    t   840000.0     PI    Nelson
# 39      Airport West   50 Bedford St      3    h   730000.0     VB    Nelson
# 40      Airport West   50 Bedford St      3    h   770000.0     SP    Nelson
# 41      Airport West      23 Hart St      2    h   603000.0      S    Nelson
# 42      Airport West  1/80 Hawker St      3    t   700000.0      S      Brad
# ...              ...             ...    ...  ...        ...    ...       ...
# 13575  Wheelers Hill    12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown   77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown     83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown    96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville      6 Agnes St      4    h  1285000.0     SP   Village
#
# ...

# %%
unique_Regionname = df.Regionname.unique()

# %%
from ipywidgets import Layout

regions = widgets.SelectMultiple(
    options = unique_Regionname.tolist(),
    value = ['Western Metropolitan', 'South-Eastern Metropolitan'],
    description='Region',
    disabled=False,
    layout = Layout(width='50%', height='80px', display='flex')
)

# %%
regions
# Out:
# SelectMultiple(description='Region', index=(1, 4), layout=Layout(display='flex', height='80px', width='50%'), …

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
widgets.interactive(update_map, district = district, category = category, limit=limit_case)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e1065f3e9ff5> in <module>
# ----> 1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
#       2 widgets.interactive(update_map, district = district, category = category, limit=limit_case)
#
# NameError: name 'plt' is not defined
