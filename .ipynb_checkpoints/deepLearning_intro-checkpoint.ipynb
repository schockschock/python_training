# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %%
#import data
data_path='cereal.csv'
cereal_df = pd.read_csv(data_path)
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
cereal_df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
# Create a network with 1 linear unit
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[3])
])

# %%
# Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# %%
cereal_df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=4, activation='relu', input_shape=[2]),
    layers.Dense(units=3, activation='relu'),
    # the linear output layer 
    layers.Dense(units=1),
])

# %%
model.weights
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(2, 4) dtype=float32, numpy=
#  array([[ 0.96079993, -0.5353534 ,  0.7005508 ,  0.7869921 ],
#         [ 0.562238  , -0.49116135, -0.92480636,  0.9517739 ]],
#        dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(4,) dtype=float32, numpy=array([0., 0., 0., 0.], dtype=float32)>,
#  <tf.Variable 'dense_2/kernel:0' shape=(4, 3) dtype=float32, numpy=
#  array([[ 0.25105965,  0.05004692, -0.36253625],
#         [-0.24747694, -0.4426371 , -0.69107354],
#         [-0.71088296,  0.36683285, -0.888224  ],
#         [ 0.0526942 ,  0.75885105,  0.07082033]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([0., 0., 0.], dtype=float32)>,
#  <tf.Variable 'dense_3/kernel:0' shape=(3, 1) dtype=float32, numpy=
#  array([[-0.3902489 ],
#         [ 1.2004434 ],
#         [ 0.17001784]], dtype=float32)>,
#  <tf.Variable 'dense_3/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
#compile the loss function and the optimizer to the model 
model.compile(
    optimizer="adam",
    loss="mae",
)

# %%
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ## training of cereals df to predict rating

# %%
from IPython.display import display

# %%
df_train = cereal_df.sample(frac=0.7, random_state=0)
df_valid = cereal_df.drop(df_train.index)

#remove non-numeric columns
df_train = df_train.select_dtypes(['number'])
df_valid = df_valid.select_dtypes(['number'])

display(df_train.head(4))
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 48       120        2    1     190    0.0   15.0       9      40        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 59       100        3    2     140    2.5   10.5       8     140        25
# 54        50        1    0       0    0.0   13.0       0      15         0
#
#     shelf  weight  cups     rating
# 48      2     1.0  0.67  29.924285
# 74      1     1.0  0.67  49.787445
# 59      3     1.0  0.50  39.703400
# 54      3     0.5  1.00  60.756112

# %%
# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('rating', axis=1)
X_valid = df_valid.drop('rating', axis=1)
y_train = df_train['rating']
y_valid = df_valid['rating']

# %%
print(X_train.shape)
# Out:
# (54, 12)

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[12]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=10,
)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 415ms/step - loss: 0.3196 - val_loss: 0.2043
# Epoch 2/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1926 - val_loss: 0.1866
# Epoch 3/10
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1701 - val_loss: 0.1293
# Epoch 4/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1159 - val_loss: 0.1164
# Epoch 5/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1033 - val_loss: 0.0980
# Epoch 6/10
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0744 - val_loss: 0.0970
# Epoch 7/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0860 - val_loss: 0.0787
# Epoch 8/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0662 - val_loss: 0.0723
# Epoch 9/10
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0554 - val_loss: 0.0693
# Epoch 10/10
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0590 - val_loss: 0.0515

# %%
# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot();
